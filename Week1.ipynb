# %% [markdown]
# <a href="https://colab.research.google.com/github/kdch1204/Dacon-Practice/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/dirve')
# Out:
# Mounted at /content/dirve

# %%
import os
import pandas as pd

print(f"현재 디렉토리 위치: {os.getcwd()}")
data_path = '/content/dirve/MyDrive/Dacon school/data/'
train = pd.read_csv(data_path + 'train.csv')
test_x = pd.read_csv(data_path + 'test_x.csv')
# Out:
# 현재 디렉토리 위치: /content

# %%
train.loc[:,'QaA': 'QtE']
# Out:
#        QaA   QaE  QbA   QbE  QcA   QcE  QdA   QdE  QeA   QeE  ...  QpA    QpE  \
# 0      3.0   363  4.0  1370  5.0   997  1.0  1024  2.0  1577  ...  2.0    924
# 1      5.0   647  5.0  1313  3.0  3387  5.0  2969  1.0  4320  ...  5.0   2414
# 2      4.0  1623  1.0  1480  1.0  1021  4.0  3374  5.0  1333  ...  1.0   1131
# 3      3.0   504  3.0  2311  4.0   992  3.0  3245  1.0   357  ...  4.0  23868
# 4      1.0   927  1.0   707  5.0   556  2.0  1062  1.0  1014  ...  4.0   1140
# ...    ...   ...  ...   ...  ...   ...  ...   ...  ...   ...  ...  ...    ...
# 45527  2.0  1050  5.0   619  4.0   328  1.0   285  1.0   602  ...  4.0    439
# 45528  2.0   581  3.0  1353  4.0  1164  1.0   798  3.0  1680  ...  4.0    719
# 45529  4.0   593  1.0   857  1.0  1047  4.0  1515  5.0  1690  ...  1.0   1200
# 45530  1.0   747  3.0  1331  4.0   892  2.0  1281  1.0  1328  ...  1.0    913
# 45531  3.0   496  5.0  1827  5.0   754  3.0  1117  1.0   432  ...  4.0    620
#
# ...

# %%
train.loc[:, 'age_group': 'religion']
# Out:
#       age_group  education  engnat  familysize  gender  hand  married   race  \
# 0           30s          2       1           4  Female     1        3  White
# 1           20s          4       2           3  Female     1        1  Asian
# 2           30s          3       1           3    Male     1        2  White
# 3           20s          4       2           0  Female     1        1  Asian
# 4           20s          3       1           2    Male     1        2  White
# ...         ...        ...     ...         ...     ...   ...      ...    ...
# 45527       10s          2       1           1  Female     3        1  White
# 45528       30s          2       1           2    Male     1        1  White
# 45529       10s          2       1           1  Female     1        1  White
# 45530       40s          4       1           2    Male     3        1  White
# 45531       20s          2       1           3    Male     1        1  White
#
#               religion
# ...

# %%
train.loc[:, 'tp01':'tp10']
# Out:
#        tp01  tp02  tp03  tp04  tp05  tp06  tp07  tp08  tp09  tp10
# 0         2     2     2     1     2     1     7     4     4     3
# 1         1     1     0     0     1     2     3     4     0     4
# 2         2     3     1     5     3     4     2     6     1     3
# 3         2     4     1     1     1     3     1     3     1     3
# 4         1     1     1     6     0     2     0     6     2     6
# ...     ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 45527     1     2     6     1     2     6     3     0     6     4
# 45528     2     2     2     3     1     3     3     4     1     5
# 45529     4     4     2     4     0     1     0     2     1     6
# 45530     1     2     0     4     0     1     3     2     2     4
# 45531     3     2     1     2     3     0     2     3     1     2
#
# [45532 rows x 10 columns]

# %%
train.loc[:, [column for column in train.columns if (column.startswith("Q") & column.endswith("A"))]]
# Out:
#        QaA  QbA  QcA  QdA  QeA  QfA  QgA  QhA  QiA  QjA  QkA  QlA  QmA  QnA  \
# 0      3.0  4.0  5.0  1.0  2.0  5.0  2.0  4.0  5.0  4.0  4.0  4.0  2.0  5.0
# 1      5.0  5.0  3.0  5.0  1.0  3.0  1.0  1.0  5.0  3.0  5.0  4.0  1.0  5.0
# 2      4.0  1.0  1.0  4.0  5.0  1.0  4.0  1.0  3.0  2.0  5.0  5.0  2.0  4.0
# 3      3.0  3.0  4.0  3.0  1.0  2.0  4.0  3.0  5.0  4.0  3.0  4.0  4.0  4.0
# 4      1.0  1.0  5.0  2.0  1.0  2.0  1.0  1.0  5.0  5.0  5.0  5.0  4.0  2.0
# ...    ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...  ...
#